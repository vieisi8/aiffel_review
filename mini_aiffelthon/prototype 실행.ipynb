# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install python-multipart
# !pip install pyngrok
# !pip install ollama
# !pip install -U langchain-ollama
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import time

# !curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve &
time.sleep(5)
# !ollama create EEVE-Korean-10.8B -f '/content/drive/MyDrive/Colab Notebooks/caloriecheck_exp_코드파일/eeve_모델 /Modelfile'
# !ollama list
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# nohup: appending output to 'nohup.out'
# ...

# %%
! nohup python '/content/drive/MyDrive/Colab Notebooks/caloriecheck_exp_코드파일/prototype fast_api/prototype_sh.py' &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !ngrok config add-authtoken 2p3x0KL08c739xU7pukbuBwXMvn_88ALas9BkcwCopD8rrm9V
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

# ngrok 터널 생성
public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")
# Out:
# Public URL: NgrokTunnel: "https://b201-35-238-129-134.ngrok-free.app" -> "http://localhost:8000"
